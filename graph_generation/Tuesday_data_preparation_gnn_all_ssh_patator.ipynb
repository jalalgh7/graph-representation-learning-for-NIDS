# %%
import pickle 
import numpy as np
import pandas as pd
import statistics
from PIL import Image
import os 
import random
import time
import matplotlib.pyplot as plt
import netaddr

# %%
import dgl
import torch
import torch.nn as nn
import dgl.function as fn
import dgl.nn as dglnn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
#pip install netaddr

# %%
#directory should change based on the device, for laptop it should be users//jalal for office desktop it is users//jghadermazi

# %%
wed_data = pd.read_pickle(r'C:\\Users\\Jalal\\Box\\GAN Project\\Sample data\\Tuesday_Packet_Level_Data.pkl')

# %%
df1 = wed_data.copy()

# %%
del wed_data

# %%
df1[['Payload']] = df1[['Payload']].replace('', '00')

# %%
df1
# Out:
#                    Epoch Time      Source IP         Dst IP  Source Port  \
# 0        1499170800.000003000    13.107.4.50  192.168.10.14           80
# 1        1499170800.000123000  192.168.10.14    13.107.4.50        50128
# 2        1499170800.000196000    13.107.4.50  192.168.10.14           80
# 3        1499170800.000388000    13.107.4.50  192.168.10.14           80
# 4        1499170800.000430000  192.168.10.14    13.107.4.50        50128
# ...                       ...            ...            ...          ...
# 4072428  1499171464.556106000  192.168.10.50     172.16.0.1           21
# 4072429  1499171464.556259000    13.107.4.50  192.168.10.15           80
# 4072430  1499171464.556366000    13.107.4.50  192.168.10.15           80
# 4072431  1499171464.556645000    13.107.4.50  192.168.10.15           80
# 4072432  1499171464.556837000    13.107.4.50  192.168.10.15           80
#
#          Dst Port Stream Index Sequence Number                    Eth Header  \
# 0           50128         5612       211623539  b8ac6f3607ee00c1b114eb310800
# 1              80         5612           20954  00c1b114eb31b8ac6f3607ee0800
# 2           50128         5612       211624999  b8ac6f3607ee00c1b114eb310800
# 3           50128         5612       211627919  b8ac6f3607ee00c1b114eb310800
# 4              80         5612           20954  00c1b114eb31b8ac6f3607ee0800
# ...           ...          ...             ...                           ...
# 4072428     53654        10076              55  00c1b114eb310019b90a69f10800
# 4072429     50580         9011       657167079  001e4fd4ca2800c1b114eb310800
# 4072430     50580         9011       657171459  001e4fd4ca2800c1b114eb310800
# 4072431     50580         9011       657172919  001e4fd4ca2800c1b114eb310800
# 4072432     50580         9011       657174379  001e4fd4ca2800c1b114eb310800
#
#                                         IP Header  \
# 0        450005dc468640007706db420d6b0432c0a80a0e
# 1        4500002874b540008006a9c7c0a80a0e0d6b0432
# 2        45000b90468740007706d58d0d6b0432c0a80a0e
# 3        45000b90468940007706d58b0d6b0432c0a80a0e
# 4        4500002874b640008006a9c6c0a80a0e0d6b0432
# ...                                           ...
# 4072428  4500003414d740004006af01c0a80a32ac100001
# 4072429  45001144038c4000760613d40d6b0432c0a80a0f
# 4072430  450005dc038f400076061f390d6b0432c0a80a0f
# 4072431  450005dc0390400076061f380d6b0432c0a80a0f
# 4072432  45000b9003914000760619830d6b0432c0a80a0f
#
#                                                 TCP Header  \
# 0                 0050c3d06674f9b8d6f187ea501003ffce740000
# 1                 c3d00050d6f187ea66750520501006273ec80000
# 2                 0050c3d06674ff6cd6f187ea501003ffe7d50000
# 3                 0050c3d066750ad4d6f187ea501003ffe7d50000
# 4                 c3d00050d6f187ea6675163c501006272dac0000
# ...                                                    ...
# 4072428  0015d19620052f8459de7112801000e38e2f0000010108...
# 4072429           0050c5943afc9ef6c6ab5e93501003feed8a0000
# 4072430           0050c5943afcb012c6ab5e93501003fe95ed0000
# 4072431           0050c5943afcb5c6c6ab5e93501003fee5770000
# 4072432           0050c5943afcbb7ac6ab5e93501003fee7d60000
#
#                                                    Payload Direction  \
# 0        2d04ab43650cdc5e7f37f485d64ab09fa83bb3ab0389c7...       bwd
# 1                                             000000000000       bwd
# 2        189fa2c3610086100fd908edc783be4c1cbc80e041b84c...       bwd
# 3        cab71d48416f5ed737efe031bae17133f7c660084eecbe...       fwd
# 4                                             000000000000       bwd
# ...                                                    ...       ...
# 4072428                                                 00       bwd
# 4072429  4c3b16f75ac96e7a8feca0e6cf2fa31bbf97915f49cbe4...       bwd
# 4072430  29d25be7dd2726626b7eff41d89a7db674f277ad59db65...       bwd
# 4072431  2b2b51cf9e9dc9c77d74bbbdd24ffa634b22ee46f2e8bf...       bwd
# 4072432  beb93f8e99d5d031b378be72e6a7cd75fb585c3d3b0db6...       bwd
#
#          Binary Label  Class Label
# 0                 1.0          6.0
# 1                 1.0          6.0
# 2                 1.0          6.0
# 3                 1.0          6.0
# 4                 1.0          6.0
# ...               ...          ...
# 4072428           0.0          0.0
# 4072429           0.0          0.0
# 4072430           0.0          0.0
# 4072431           0.0          0.0
# 4072432           0.0          0.0
#
# [4072433 rows x 14 columns]

# %%
#benign    0
#dos slowloris    1
#dos slowhttptest   2
#dos hulk     3
#dos goldeneye    4
#heartbleed    5
#ftp patator    6
#ssh patator    7
#webattack bruteforce    8
#webattack xss     9
#webattack sql injection 10
#infiltration     11
#botnet     12
#portscan   13
#ddos     14

# %%
df1['Class Label'].value_counts()
# Out:
# 0.0    3798386
# 7.0     163311
# 6.0     110736
# Name: Class Label, dtype: int64

# %%
df = df1[df1['Class Label']== 7]

# %%
df = df.reset_index(inplace = False)

# %%
df
# Out:
#          index            Epoch Time      Source IP         Dst IP  \
# 0       110736  1499171175.501129000    13.107.4.50  192.168.10.15
# 1       110737  1499171175.501382000    13.107.4.50  192.168.10.15
# 2       110738  1499171175.501465000  192.168.10.15    13.107.4.50
# 3       110739  1499171175.501573000    13.107.4.50  192.168.10.15
# 4       110740  1499171175.501646000  192.168.10.15    13.107.4.50
# ...        ...                   ...            ...            ...
# 163306  274042  1499171197.147449000  192.168.10.14    13.107.4.50
# 163307  274043  1499171197.147474000    13.107.4.50  192.168.10.14
# 163308  274044  1499171197.147640000  192.168.10.14    13.107.4.50
# 163309  274045  1499171197.147666000    13.107.4.50  192.168.10.14
# 163310  274046  1499171197.147857000    13.107.4.50  192.168.10.14
#
#         Source Port  Dst Port Stream Index Sequence Number  \
# 0                80     50023         7455       785742636
# 1                80     50023         7455       785744096
# 2             50023        80         7455           65199
# 3                80     50023         7455       785745556
# 4             50023        80         7455           65199
# ...             ...       ...          ...             ...
# 163306        50128        80         5612          157181
# 163307           80     50128         5612      2087935803
# 163308        50128        80         5612          157181
# 163309           80     50128         5612      2087940183
# 163310           80     50128         5612      2087943103
#
#                           Eth Header  \
# 0       001e4fd4ca2800c1b114eb310800
# 1       001e4fd4ca2800c1b114eb310800
# 2       00c1b114eb31001e4fd4ca280800
# 3       001e4fd4ca2800c1b114eb310800
# 4       00c1b114eb31001e4fd4ca280800
# ...                              ...
# 163306  00c1b114eb31b8ac6f3607ee0800
# 163307  b8ac6f3607ee00c1b114eb310800
# 163308  00c1b114eb31b8ac6f3607ee0800
# 163309  b8ac6f3607ee00c1b114eb310800
# 163310  b8ac6f3607ee00c1b114eb310800
#
#                                        IP Header  \
# 0       450005dc405040007706e1770d6b0432c0a80a0f
# 1       450005dc405140007706e1760d6b0432c0a80a0f
# 2       4500002811fe400080060c7ec0a80a0f0d6b0432
# 3       450005dc405240007706e1750d6b0432c0a80a0f
# 4       4500002811ff400080060c7dc0a80a0f0d6b0432
# ...                                          ...
# 163306  45000028120a400080060c73c0a80a0e0d6b0432
# 163307  45001144020540007706145c0d6b0432c0a80a0e
# 163308  45000028120b400080060c72c0a80a0e0d6b0432
# 163309  45000b900208400077061a0d0d6b0432c0a80a0e
# 163310  450005dc020a400077061fbf0d6b0432c0a80a0e
#
#                                       TCP Header  \
# 0       0050c3675efc46fef7d3d63e5010040160b60000
# 1       0050c3675efc4cb2f7d3d63e5010040175bb0000
# 2       c3670050f7d3d63e5efc581a5010061684890000
# 3       0050c3675efc5266f7d3d63e501004011f2e0000
# 4       c3670050f7d3d63e5efc5dce501006167ed50000
# ...                                          ...
# 163306  c3d00050d6f39c0dd64b4b9c5010069173e60000
# 163307  0050c3d0d64b3a80d6f39c0d501003ffed890000
# 163308  c3d00050d6f39c0dd64b5150501006916e320000
# 163309  0050c3d0d64b4b9cd6f39c0d501003ffe7d50000
# 163310  0050c3d0d64b5704d6f39c0d501003ffee5e0000
#
#                                                   Payload Direction  \
# 0       a631f6e21ba2ff1599d344cc2ad4af0d874ee372e47d89...       fwd
# 1       4c2b55634e4d47f8231d82512f40c602fddb8681278a8f...       fwd
# 2                                            000000000000       fwd
# 3       fcf0d1a5b576b0523d00e67e87db22a671a5c388969e46...       fwd
# 4                                            000000000000       bwd
# ...                                                   ...       ...
# 163306                                       000000000000       bwd
# 163307  56ff935994abe3e8b1a87f9554115f90587efe34970412...       fwd
# 163308                                       000000000000       fwd
# 163309  1e7990a7cc9244cfd74e565995d30ce6b76a49aaa9472a...       bwd
# 163310  355213d6e35a959bbfe2a2ece4e2bad009d9900a48befd...       fwd
#
#         Binary Label  Class Label
# 0                1.0          7.0
# 1                1.0          7.0
# 2                1.0          7.0
# 3                1.0          7.0
# 4                1.0          7.0
# ...              ...          ...
# 163306           1.0          7.0
# 163307           1.0          7.0
# 163308           1.0          7.0
# 163309           1.0          7.0
# 163310           1.0          7.0
#
# [163311 rows x 15 columns]

# %%
ip_header_lst = []

for i in range(len(df)):
    x = df['IP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 9, 12, 13, 14, 15, 16, 17, 18, 19])
    
    output = np.abs(output.astype(float))/255
    ip_header_lst.append(output)
    
df['IP Header Array'] = ip_header_lst

# %%
tcp_header_lst = []

for i in range(len(df)):
    x = df['TCP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 2, 3])
    output = np.abs(output.astype(float))/255
    
    tcp_header_lst.append(output)
    
df['TCP Header Array'] = tcp_header_lst

# %%
df['pkt_header_values'] = df.apply(lambda x : (np.append(x['IP Header Array'], x['TCP Header Array'])), axis=1)

# %%
new_cols = ['Source IP', 'Dst IP', 'Source Port', 'Dst Port','Epoch Time','Stream Index', 'Sequence Number', 'Direction', 'pkt_header_values']
df = df[new_cols]

# %%
# 70% of benign data for train, 30% for test benign

# %%
#random.seed(0)
#mlist = random.sample(streams_lst, 61492)

# %%
#len(imlist)

# %%
#df_train = df.loc[df['Stream Index'].isin(imlist)]
#df_train = df_train.reset_index(inplace = False)

# %%
#df_test = df.loc[~df['Stream Index'].isin(imlist)]
#df_test = df_test.reset_index(inplace = False)

# %%
#streams_lst1 = list(df_test['Stream Index'].unique())

# %%
#len(streams_lst1)

# %%
df
# Out:
#             Source IP         Dst IP  Source Port  Dst Port  \
# 0         13.107.4.50  192.168.10.15           80     50023
# 1         13.107.4.50  192.168.10.15           80     50023
# 2       192.168.10.15    13.107.4.50        50023        80
# 3         13.107.4.50  192.168.10.15           80     50023
# 4       192.168.10.15    13.107.4.50        50023        80
# ...               ...            ...          ...       ...
# 163306  192.168.10.14    13.107.4.50        50128        80
# 163307    13.107.4.50  192.168.10.14           80     50128
# 163308  192.168.10.14    13.107.4.50        50128        80
# 163309    13.107.4.50  192.168.10.14           80     50128
# 163310    13.107.4.50  192.168.10.14           80     50128
#
#                   Epoch Time Stream Index Sequence Number Direction  \
# 0       1499171175.501129000         7455       785742636       fwd
# 1       1499171175.501382000         7455       785744096       fwd
# 2       1499171175.501465000         7455           65199       fwd
# 3       1499171175.501573000         7455       785745556       fwd
# 4       1499171175.501646000         7455           65199       bwd
# ...                      ...          ...             ...       ...
# 163306  1499171197.147449000         5612          157181       bwd
# 163307  1499171197.147474000         5612      2087935803       fwd
# 163308  1499171197.147640000         5612          157181       fwd
# 163309  1499171197.147666000         5612      2087940183       bwd
# 163310  1499171197.147857000         5612      2087943103       fwd
#
#                                         pkt_header_values
# 0       [0.0196078431372549, 0.8627450980392157, 0.250...
# 1       [0.0196078431372549, 0.8627450980392157, 0.250...
# 2       [0.0, 0.1568627450980392, 0.06666666666666667,...
# 3       [0.0196078431372549, 0.8627450980392157, 0.250...
# 4       [0.0, 0.1568627450980392, 0.06666666666666667,...
# ...                                                   ...
# 163306  [0.0, 0.1568627450980392, 0.07058823529411765,...
# 163307  [0.06666666666666667, 0.26666666666666666, 0.0...
# 163308  [0.0, 0.1568627450980392, 0.07058823529411765,...
# 163309  [0.043137254901960784, 0.5647058823529412, 0.0...
# 163310  [0.0196078431372549, 0.8627450980392157, 0.007...
#
# [163311 rows x 9 columns]

# %%
streams_lst = list(df['Stream Index'].unique())
print('Total number of flows in class:', len(streams_lst))    
random.shuffle(streams_lst)

# Directory path where to save the CSV files
directory_path = 'Tuesday_ssh_all/'

for PKT in range(2, 16):
    
    file_name = f'tuesday_ssh_{PKT}pkt.csv'
    file_path = directory_path + file_name
    

    data = []
    num_pkt = PKT
    pkt_val_pad = [0] * 25


    for j in range(len(streams_lst)):

        df_stream = df[df['Stream Index'] == streams_lst[j]]


        df_stream = df_stream.sort_values(by = 'Epoch Time')
        df_stream = df_stream.reset_index(drop=True)


        if len(df_stream) >= num_pkt:

            src_node = (int(netaddr.IPAddress(df_stream['Source IP'][0])), int(df_stream['Source Port'][0]))
            dst_node = (int(netaddr.IPAddress(df_stream['Dst IP'][0])), int(df_stream['Dst Port'][0]))
            stream_no = df_stream['Stream Index'][0]

            pkt_val_seq = []

            for k in range(0, num_pkt):

                pkt_val = []
                if df_stream['Direction'][k] == 'fwd':
                    pkt_val = [*df_stream['pkt_header_values'][k], *pkt_val_pad]
                else:
                    pkt_val = [*pkt_val_pad, *df_stream['pkt_header_values'][k]]

                pkt_val_seq.extend(pkt_val)

            data.append([src_node, dst_node, stream_no, pkt_val_seq])

    df2 = pd.DataFrame(data, columns= ['src_node', 'dst_node', 'stream_number', 'pkt_vals'])
    
    df2.to_csv(file_path, index=False)
# Out:
# Total number of flows in class: 457
