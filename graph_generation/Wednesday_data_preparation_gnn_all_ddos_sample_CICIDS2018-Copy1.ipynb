# %%
import pickle 
import numpy as np
import pandas as pd
import statistics
from PIL import Image
import os 
import random
import time
import matplotlib.pyplot as plt
import netaddr

# %%
#pip install netaddr

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\Jalal\\Box\\GNN Project\\Code files'

# %%
#directory should change based on the device, for laptop it should be users//jalal for office desktop it is users//jghadermazi

# %%
wed_data = pd.read_pickle(r'C:\\Users\\Jalal\\Box\\GNN Project\\CICIDS2018\\DDoS-10\\Wednesday-21-02-2018_Packet_Level_Data_DDoS.pkl')

# %%
df1 = wed_data.copy()

# %%
df1[['Payload']] = df1[['Payload']].replace('', '00')

# %%
df1
# Out:
#                    Epoch Time       Source IP          Dst IP  Source Port  \
# 0        1519236677.295398000  18.218.229.235    172.31.69.28        52294
# 1        1519236677.295406000    172.31.69.28  18.218.229.235           80
# 2        1519236677.295484000  18.218.229.235    172.31.69.28        52295
# 3        1519236677.295487000    172.31.69.28  18.218.229.235           80
# 4        1519236677.295570000  18.218.229.235    172.31.69.28        52296
# ...                       ...             ...             ...          ...
# 1091956  1519239946.406801000    172.31.69.28  18.218.229.235           80
# 1091957  1519239946.407105000  18.218.229.235    172.31.69.28        63479
# 1091958  1519239946.407107000    172.31.69.28  18.218.229.235           80
# 1091959  1519239946.407920000  18.218.229.235    172.31.69.28        63480
# 1091960  1519239946.407922000    172.31.69.28  18.218.229.235           80
#
#          Dst Port Stream Index Sequence Number                    Eth Header  \
# 0              80         1798               0  029e424890aa02ca69c46d060800
# 1           52294         1798               0  02ca69c46d06029e424890aa0800
# 2              80         1799               0  029e424890aa02ca69c46d060800
# 3           52295         1799               0  02ca69c46d06029e424890aa0800
# 4              80         1800               0  029e424890aa02ca69c46d060800
# ...           ...          ...             ...                           ...
# 1091956     63475      1082348             937  02ca69c46d06029e424890aa0800
# 1091957        80      1082356             269  029e424890aa02ca69c46d060800
# 1091958     63479      1082356             937  02ca69c46d06029e424890aa0800
# 1091959        80      1082357             269  029e424890aa02ca69c46d060800
# 1091960     63480      1082357             937  02ca69c46d06029e424890aa0800
#
#                                         IP Header  \
# 0        45020034234740007f06ee7912dae5ebac1f451c
# 1        4500003400004000400650c3ac1f451c12dae5eb
# 2        45020034234840007f06ee7812dae5ebac1f451c
# 3        4500003400004000400650c3ac1f451c12dae5eb
# 4        45020034234940007f06ee7712dae5ebac1f451c
# ...                                           ...
# 1091956  450000280dc7400040064308ac1f451c12dae5eb
# 1091957  45000028791540007f0698b912dae5ebac1f451c
# 1091958  45000028a4b140004006ac1dac1f451c12dae5eb
# 1091959  45000028791640007f0698b812dae5ebac1f451c
# 1091960  45000028e6cd400040066a01ac1f451c12dae5eb
#
#                                        TCP Header                TCP Option  \
# 0        cc46005004c0b5410000000080c2fffffdb90000  020405b40103030501010402
# 1        0050cc463572c80104c0b54280126903ea270000  020423010101040201030307
# 2        cc4700508627a1490000000080c2ffff90490000  020405b40103030501010402
# 3        0050cc47fc64ec208627a14a80126903ea270000  020423010101040201030307
# 4        cc4800501da7f48b0000000080c2ffffa5860000  020405b40103030501010402
# ...                                           ...                       ...
# 1091956  0050f7f3c10f9c71484fd5b7501000dbea1b0000
# 1091957  f7f700503eb421a7f198354b50117fe2c6680000
# 1091958  0050f7f7f198354b3eb421a8501000dbea1b0000
# 1091959  f7f80050341200526434776f50117fe23d9f0000
# 1091960  0050f7f86434776f34120053501000dbea1b0000
#
#         Payload Direction  Binary Label  Class Label
# 0            00       fwd             1           10
# 1            00       bwd             1           10
# 2            00       fwd             1           10
# 3            00       bwd             1           10
# 4            00       fwd             1           10
# ...         ...       ...           ...          ...
# 1091956      00       bwd             1           10
# 1091957      00       fwd             1           10
# 1091958      00       bwd             1           10
# 1091959      00       fwd             1           10
# 1091960      00       bwd             1           10
#
# [1091961 rows x 15 columns]

# %%
#Web attack-Brute Force 1
# Web attack-XSS 2
# Web attack-Sql injection 3
# FTP patator 4
# SSH Patator 5
# DoS GoldenEye 6
# DoS Slowloris 7
# DoS Hulk 8
# DoS Slowhttptest 9
# DDoS 10
# Infiltration 11

# %%
df1['Class Label'].value_counts()
# Out:
# 10    1091961
# Name: Class Label, dtype: int64

# %%
df = df1[df1['Class Label']== 10]

# %%
df = df.reset_index(inplace = False)

# %%
df
# Out:
#            index            Epoch Time       Source IP          Dst IP  \
# 0              0  1519236677.295398000  18.218.229.235    172.31.69.28
# 1              1  1519236677.295406000    172.31.69.28  18.218.229.235
# 2              2  1519236677.295484000  18.218.229.235    172.31.69.28
# 3              3  1519236677.295487000    172.31.69.28  18.218.229.235
# 4              4  1519236677.295570000  18.218.229.235    172.31.69.28
# ...          ...                   ...             ...             ...
# 1091956  1091956  1519239946.406801000    172.31.69.28  18.218.229.235
# 1091957  1091957  1519239946.407105000  18.218.229.235    172.31.69.28
# 1091958  1091958  1519239946.407107000    172.31.69.28  18.218.229.235
# 1091959  1091959  1519239946.407920000  18.218.229.235    172.31.69.28
# 1091960  1091960  1519239946.407922000    172.31.69.28  18.218.229.235
#
#          Source Port  Dst Port Stream Index Sequence Number  \
# 0              52294        80         1798               0
# 1                 80     52294         1798               0
# 2              52295        80         1799               0
# 3                 80     52295         1799               0
# 4              52296        80         1800               0
# ...              ...       ...          ...             ...
# 1091956           80     63475      1082348             937
# 1091957        63479        80      1082356             269
# 1091958           80     63479      1082356             937
# 1091959        63480        80      1082357             269
# 1091960           80     63480      1082357             937
#
#                            Eth Header  \
# 0        029e424890aa02ca69c46d060800
# 1        02ca69c46d06029e424890aa0800
# 2        029e424890aa02ca69c46d060800
# 3        02ca69c46d06029e424890aa0800
# 4        029e424890aa02ca69c46d060800
# ...                               ...
# 1091956  02ca69c46d06029e424890aa0800
# 1091957  029e424890aa02ca69c46d060800
# 1091958  02ca69c46d06029e424890aa0800
# 1091959  029e424890aa02ca69c46d060800
# 1091960  02ca69c46d06029e424890aa0800
#
#                                         IP Header  \
# 0        45020034234740007f06ee7912dae5ebac1f451c
# 1        4500003400004000400650c3ac1f451c12dae5eb
# 2        45020034234840007f06ee7812dae5ebac1f451c
# 3        4500003400004000400650c3ac1f451c12dae5eb
# 4        45020034234940007f06ee7712dae5ebac1f451c
# ...                                           ...
# 1091956  450000280dc7400040064308ac1f451c12dae5eb
# 1091957  45000028791540007f0698b912dae5ebac1f451c
# 1091958  45000028a4b140004006ac1dac1f451c12dae5eb
# 1091959  45000028791640007f0698b812dae5ebac1f451c
# 1091960  45000028e6cd400040066a01ac1f451c12dae5eb
#
#                                        TCP Header                TCP Option  \
# 0        cc46005004c0b5410000000080c2fffffdb90000  020405b40103030501010402
# 1        0050cc463572c80104c0b54280126903ea270000  020423010101040201030307
# 2        cc4700508627a1490000000080c2ffff90490000  020405b40103030501010402
# 3        0050cc47fc64ec208627a14a80126903ea270000  020423010101040201030307
# 4        cc4800501da7f48b0000000080c2ffffa5860000  020405b40103030501010402
# ...                                           ...                       ...
# 1091956  0050f7f3c10f9c71484fd5b7501000dbea1b0000
# 1091957  f7f700503eb421a7f198354b50117fe2c6680000
# 1091958  0050f7f7f198354b3eb421a8501000dbea1b0000
# 1091959  f7f80050341200526434776f50117fe23d9f0000
# 1091960  0050f7f86434776f34120053501000dbea1b0000
#
#         Payload Direction  Binary Label  Class Label
# 0            00       fwd             1           10
# 1            00       bwd             1           10
# 2            00       fwd             1           10
# 3            00       bwd             1           10
# 4            00       fwd             1           10
# ...         ...       ...           ...          ...
# 1091956      00       bwd             1           10
# 1091957      00       fwd             1           10
# 1091958      00       bwd             1           10
# 1091959      00       fwd             1           10
# 1091960      00       bwd             1           10
#
# [1091961 rows x 16 columns]

# %%
ip_header_lst = []

for i in range(len(df)):
    x = df['IP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 9, 12, 13, 14, 15, 16, 17, 18, 19])
    
    output = np.abs(output.astype(float))/255
    ip_header_lst.append(output)
    
df['IP Header Array'] = ip_header_lst

# %%
tcp_header_lst = []

for i in range(len(df)):
    x = df['TCP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 2, 3])
    output = np.abs(output.astype(float))/255
    
    tcp_header_lst.append(output)
    
df['TCP Header Array'] = tcp_header_lst

# %%
df['pkt_header_values'] = df.apply(lambda x : (np.append(x['IP Header Array'], x['TCP Header Array'])), axis=1)

# %%
new_cols = ['Source IP', 'Dst IP', 'Source Port', 'Dst Port','Epoch Time','Stream Index', 'Sequence Number', 'Direction', 'pkt_header_values']
df = df[new_cols]

# %%
df
# Out:
#               Source IP          Dst IP  Source Port  Dst Port  \
# 0        18.218.229.235    172.31.69.28        52294        80
# 1          172.31.69.28  18.218.229.235           80     52294
# 2        18.218.229.235    172.31.69.28        52295        80
# 3          172.31.69.28  18.218.229.235           80     52295
# 4        18.218.229.235    172.31.69.28        52296        80
# ...                 ...             ...          ...       ...
# 1091956    172.31.69.28  18.218.229.235           80     63475
# 1091957  18.218.229.235    172.31.69.28        63479        80
# 1091958    172.31.69.28  18.218.229.235           80     63479
# 1091959  18.218.229.235    172.31.69.28        63480        80
# 1091960    172.31.69.28  18.218.229.235           80     63480
#
#                    Epoch Time Stream Index Sequence Number Direction  \
# 0        1519236677.295398000         1798               0       fwd
# 1        1519236677.295406000         1798               0       bwd
# 2        1519236677.295484000         1799               0       fwd
# 3        1519236677.295487000         1799               0       bwd
# 4        1519236677.295570000         1800               0       fwd
# ...                       ...          ...             ...       ...
# 1091956  1519239946.406801000      1082348             937       bwd
# 1091957  1519239946.407105000      1082356             269       fwd
# 1091958  1519239946.407107000      1082356             937       bwd
# 1091959  1519239946.407920000      1082357             269       fwd
# 1091960  1519239946.407922000      1082357             937       bwd
#
#                                          pkt_header_values
# 0        [0.0, 0.20392156862745098, 0.13725490196078433...
# 1        [0.0, 0.20392156862745098, 0.0, 0.0, 0.2509803...
# 2        [0.0, 0.20392156862745098, 0.13725490196078433...
# 3        [0.0, 0.20392156862745098, 0.0, 0.0, 0.2509803...
# 4        [0.0, 0.20392156862745098, 0.13725490196078433...
# ...                                                    ...
# 1091956  [0.0, 0.1568627450980392, 0.050980392156862744...
# 1091957  [0.0, 0.1568627450980392, 0.4745098039215686, ...
# 1091958  [0.0, 0.1568627450980392, 0.6431372549019608, ...
# 1091959  [0.0, 0.1568627450980392, 0.4745098039215686, ...
# 1091960  [0.0, 0.1568627450980392, 0.9019607843137255, ...
#
# [1091961 rows x 9 columns]

# %%
# 70% of benign data for train, 30% for test benign

# %%
streams_lst = list(df['Stream Index'].unique())
streams_lst = streams_lst[0:2000]
print('Total number of flows in class:', len(streams_lst))    
random.shuffle(streams_lst)

# Directory path where to save the CSV files
directory_path = '2018_ddos/'

for PKT in range(2, 16):
    
    file_name = f'2018_ddos_{PKT}pkt.csv'
    file_path = directory_path + file_name
    

    data = []
    num_pkt = PKT
    pkt_val_pad = [0] * 25


    for j in range(len(streams_lst)):

        df_stream = df[df['Stream Index'] == streams_lst[j]]


        df_stream = df_stream.sort_values(by = 'Epoch Time')
        df_stream = df_stream.reset_index(drop=True)


        if len(df_stream) >= num_pkt:

            src_node = (int(netaddr.IPAddress(df_stream['Source IP'][0])), int(df_stream['Source Port'][0]))
            dst_node = (int(netaddr.IPAddress(df_stream['Dst IP'][0])), int(df_stream['Dst Port'][0]))
            stream_no = df_stream['Stream Index'][0]

            pkt_val_seq = []

            for k in range(0, num_pkt):

                pkt_val = []
                if df_stream['Direction'][k] == 'fwd':
                    pkt_val = [*df_stream['pkt_header_values'][k], *pkt_val_pad]
                else:
                    pkt_val = [*pkt_val_pad, *df_stream['pkt_header_values'][k]]

                pkt_val_seq.extend(pkt_val)

            data.append([src_node, dst_node, stream_no, pkt_val_seq])

    df1 = pd.DataFrame(data, columns= ['src_node', 'dst_node', 'stream_number', 'pkt_vals'])
    
    df1.to_csv(file_path, index=False)
# Out:
# Total number of flows in class: 2000
