# %%
import pickle 
import numpy as np
import pandas as pd
import statistics
from PIL import Image
import os 
import random
import time
import matplotlib.pyplot as plt
import netaddr

# %%
#pip install netaddr

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\jghadermazi\\Box\\GNN Project\\Code files'

# %%
#directory should change based on the device, for laptop it should be users//jalal for office desktop it is users//jghadermazi

# %%
wed_data = pd.read_pickle(r'C:\\Users\\jghadermazi\\Box\\GAN Project\\Sample data\\Friday_Packet_Level_Data.pkl')

# %%
df1 = wed_data.copy()

# %%
df1[['Payload']] = df1[['Payload']].replace('', '00')

# %%
df1
# Out:
#                    Epoch Time       Source IP          Dst IP  Source Port  \
# 0        1499432653.990571000    192.168.10.9  205.174.165.73         1841
# 1        1499432653.991397000  205.174.165.73    192.168.10.9         8080
# 2        1499432653.991520000    192.168.10.9  205.174.165.73         1841
# 3        1499432653.992542000    192.168.10.9  205.174.165.73         1841
# 4        1499432653.993057000  205.174.165.73    192.168.10.9         8080
# ...                       ...             ...             ...          ...
# 5260217  1499454300.212460000  172.217.12.205   192.168.10.14          443
# 5260218  1499454300.212688000  172.217.12.205   192.168.10.14          443
# 5260219  1499454300.212736000  172.217.12.205   192.168.10.14          443
# 5260220  1499454300.212738000  172.217.12.205   192.168.10.14          443
# 5260221  1499454300.214231000  93.184.216.172   192.168.10.14          443
#
#          Dst Port Stream Index Sequence Number                    Eth Header  \
# 0            8080        13099               0  00c1b114eb31b8ac6f1d1f6c0800
# 1            1841        13099               0  b8ac6f1d1f6c00c1b114eb310800
# 2            8080        13099               1  00c1b114eb31b8ac6f1d1f6c0800
# 3            8080        13099               1  00c1b114eb31b8ac6f1d1f6c0800
# 4            1841        13099               1  b8ac6f1d1f6c00c1b114eb310800
# ...           ...          ...             ...                           ...
# 5260217     58093       280715            3982  b8ac6f3607ee00c1b114eb310800
# 5260218     58093       280715            4189  b8ac6f3607ee00c1b114eb310800
# 5260219     58093       280715            4562  b8ac6f3607ee00c1b114eb310800
# 5260220     58093       280715            4694  b8ac6f3607ee00c1b114eb310800
# 5260221     58096       280754            5501  b8ac6f3607ee00c1b114eb310800
#
#                                         IP Header  \
# 0        450000346c8f40008006508bc0a80a09cdaea549
# 1        45000034000040003e06ff1acdaea549c0a80a09
# 2        450000286c90400080065096c0a80a09cdaea549
# 3        450000ea6c91400080064fd3c0a80a09cdaea549
# 4        45000028822a40003e067cfccdaea549c0a80a09
# ...                                           ...
# 5260217  450000f7dfe60000340621beacd90ccdc0a80a0e
# 5260218  4500019ddfe7000034062117acd90ccdc0a80a0e
# 5260219  450000acdfe8000034062207acd90ccdc0a80a0e
# 5260220  45000056dfe900003406225cacd90ccdc0a80a0e
# 5260221  4500012a1b104000370626a35db8d8acc0a80a0e
#
#                                                 TCP Header  \
# 0        07311f905c691851000000008002200075eb0000020405...
# 1        1f90073113dd44cb5c69185280127210cb220000020405...
# 2                 07311f905c69185213dd44cc501001007d050000
# 3                 07311f905c69185213dd44cc50180100307c0000
# 4                 1f90073113dd44cc5c691914501000ed7c560000
# ...                                                    ...
# 5260217           01bbe2eda84cbf47d787ec2350180169decb0000
# 5260218           01bbe2eda84cc016d787ec2350180169e0870000
# 5260219           01bbe2eda84cc18bd787ec235018016903ef0000
# 5260220           01bbe2eda84cc20fd787ec2350180169e55a0000
# 5260221           01bbe2f014324df0b28987bb501801203b4a0000
#
#                                                    Payload Direction  \
# 0                                                       00       fwd
# 1                                                       00       bwd
# 2                                             000000000000       fwd
# 3        474554202f6170692f706f703f626f7469643d6d697461...       fwd
# 4                                             000000000000       bwd
# ...                                                    ...       ...
# 5260217  17030300ca0000000000000003b9423a0b5901a1d34005...       bwd
# 5260218  1703030170000000000000000427cfa8c91d47cda4d459...       bwd
# 5260219  170303007f000000000000000529465b5b09e2c6a7bf19...       bwd
# 5260220  170303002900000000000000066521f26029ac678a3244...       bwd
# 5260221  16030300ca040000c60000012c00c0a905c333f9859839...       bwd
#
#          Binary Label  Class Label
# 0                 1.0         12.0
# 1                 1.0         12.0
# 2                 1.0         12.0
# 3                 1.0         12.0
# 4                 1.0         12.0
# ...               ...          ...
# 5260217           0.0          0.0
# 5260218           0.0          0.0
# 5260219           0.0          0.0
# 5260220           0.0          0.0
# 5260221           0.0          0.0
#
# [5260222 rows x 14 columns]

# %%
#benign    0
#dos slowloris    1
#dos slowhttptest   2
#dos hulk     3
#dos goldeneye    4
#heartbleed    5
#ftp patator    6
#ssh patator    7
#webattack bruteforce    8
#webattack xss     9
#webattack sql injection 10
#infiltration     11
#botnet     12
#portscan   13
#ddos     14

# %%
df1['Class Label'].value_counts()
# Out:
# 0.0     3661387
# 14.0    1265657
# 13.0     323307
# 12.0       9871
# Name: Class Label, dtype: int64

# %%
df = df1[df1['Class Label']== 14]

# %%
df = df.reset_index(inplace = False)

# %%
df
# Out:
#            index            Epoch Time      Source IP         Dst IP  \
# 0         333178  1499449939.766403000     172.16.0.1  192.168.10.50
# 1         333179  1499449939.766424000  192.168.10.50     172.16.0.1
# 2         333180  1499449939.766430000  192.168.10.50     172.16.0.1
# 3         333181  1499449939.766445000     172.16.0.1  192.168.10.50
# 4         333182  1499449939.766451000  192.168.10.50     172.16.0.1
# ...          ...                   ...            ...            ...
# 1265652  1598830  1499454016.102778000     172.16.0.1  192.168.10.50
# 1265653  1598831  1499454016.102787000  192.168.10.50     172.16.0.1
# 1265654  1598832  1499454016.102841000     172.16.0.1  192.168.10.50
# 1265655  1598833  1499454016.102865000     172.16.0.1  192.168.10.50
# 1265656  1598834  1499454016.102883000  192.168.10.50     172.16.0.1
#
#          Source Port  Dst Port Stream Index Sequence Number  \
# 0              42849      9090        90014               0
# 1               1521     42849        90013               1
# 2                631     42849        90012               1
# 3              42849     51493        90015               0
# 4               9090     42849        90014               1
# ...              ...       ...          ...             ...
# 1265652        19397        80       257118               0
# 1265653           80     19397       257118               0
# 1265654        19398        80       257119               0
# 1265655        19399        80       257120               0
# 1265656           80     19398       257119               0
#
#                            Eth Header  \
# 0        0019b90a69f100c1b114eb310800
# 1        00c1b114eb310019b90a69f10800
# 2        00c1b114eb310019b90a69f10800
# 3        0019b90a69f100c1b114eb310800
# 4        00c1b114eb310019b90a69f10800
# ...                               ...
# 1265652  0019b90a69f100c1b114eb310800
# 1265653  00c1b114eb310019b90a69f10800
# 1265654  0019b90a69f100c1b114eb310800
# 1265655  0019b90a69f100c1b114eb310800
# 1265656  00c1b114eb310019b90a69f10800
#
#                                         IP Header  \
# 0        4500002c3ea300003006d53dac100001c0a80a32
# 1        45000028aff14000400613f3c0a80a32ac100001
# 2        45000028aff04000400613f4c0a80a32ac100001
# 3        4500002c5b3d00003606b2a3ac100001c0a80a32
# 4        45000028aff24000400613f2c0a80a32ac100001
# ...                                           ...
# 1265652  450000343f7f40007e064659ac100001c0a80a32
# 1265653  45000034000040004006c3d8c0a80a32ac100001
# 1265654  450000343f8040007e064658ac100001c0a80a32
# 1265655  450000343f8140007e064657ac100001c0a80a32
# 1265656  45000034000040004006c3d8c0a80a32ac100001
#
#                                                 TCP Header       Payload  \
# 0         a76123820ff6a9530000000060020400990d0000020405b4          0000
# 1                 05f1a761000000000ff6a95450140000d2470000  000000000000
# 2                 0277a761000000000ff6a95450140000d5c10000  000000000000
# 3         a761c9250ff6a9530000000060020400f3690000020405b4          0000
# 4                 2382a761000000000ff6a95450140000b4b60000  000000000000
# ...                                                    ...           ...
# 1265652  4bc50050dc82909a00000000800220001ef20000020405...            00
# 1265653  00504bc587f1afafdc82909b8012721095300000020405...            00
# 1265654  4bc60050351ace0f000000008002200088e40000020405...            00
# 1265655  4bc700507d93999d000000008002200074dc0000020405...            00
# 1265656  00504bc6df1f60be351ace1080127210f6e50000020405...            00
#
#         Direction  Binary Label  Class Label
# 0             fwd           1.0         14.0
# 1             bwd           1.0         14.0
# 2             fwd           1.0         14.0
# 3             fwd           1.0         14.0
# 4             bwd           1.0         14.0
# ...           ...           ...          ...
# 1265652       fwd           1.0         14.0
# 1265653       bwd           1.0         14.0
# 1265654       fwd           1.0         14.0
# 1265655       fwd           1.0         14.0
# 1265656       bwd           1.0         14.0
#
# [1265657 rows x 15 columns]

# %%
ip_header_lst = []

for i in range(len(df)):
    x = df['IP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 9, 12, 13, 14, 15, 16, 17, 18, 19])
    
    output = np.abs(output.astype(float))/255
    ip_header_lst.append(output)
    
df['IP Header Array'] = ip_header_lst

# %%
tcp_header_lst = []

for i in range(len(df)):
    x = df['TCP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 2, 3])
    output = np.abs(output.astype(float))/255
    
    tcp_header_lst.append(output)
    
df['TCP Header Array'] = tcp_header_lst

# %%
df['pkt_header_values'] = df.apply(lambda x : (np.append(x['IP Header Array'], x['TCP Header Array'])), axis=1)

# %%
new_cols = ['Source IP', 'Dst IP', 'Source Port', 'Dst Port','Epoch Time','Stream Index', 'Sequence Number', 'Direction', 'pkt_header_values']
df = df[new_cols]

# %%
df
# Out:
#              Source IP         Dst IP  Source Port  Dst Port  \
# 0           172.16.0.1  192.168.10.50        42849      9090
# 1        192.168.10.50     172.16.0.1         1521     42849
# 2        192.168.10.50     172.16.0.1          631     42849
# 3           172.16.0.1  192.168.10.50        42849     51493
# 4        192.168.10.50     172.16.0.1         9090     42849
# ...                ...            ...          ...       ...
# 1265652     172.16.0.1  192.168.10.50        19397        80
# 1265653  192.168.10.50     172.16.0.1           80     19397
# 1265654     172.16.0.1  192.168.10.50        19398        80
# 1265655     172.16.0.1  192.168.10.50        19399        80
# 1265656  192.168.10.50     172.16.0.1           80     19398
#
#                    Epoch Time Stream Index Sequence Number Direction  \
# 0        1499449939.766403000        90014               0       fwd
# 1        1499449939.766424000        90013               1       bwd
# 2        1499449939.766430000        90012               1       fwd
# 3        1499449939.766445000        90015               0       fwd
# 4        1499449939.766451000        90014               1       bwd
# ...                       ...          ...             ...       ...
# 1265652  1499454016.102778000       257118               0       fwd
# 1265653  1499454016.102787000       257118               0       bwd
# 1265654  1499454016.102841000       257119               0       fwd
# 1265655  1499454016.102865000       257120               0       fwd
# 1265656  1499454016.102883000       257119               0       bwd
#
#                                          pkt_header_values
# 0        [0.0, 0.17254901960784313, 0.24313725490196078...
# 1        [0.0, 0.1568627450980392, 0.6862745098039216, ...
# 2        [0.0, 0.1568627450980392, 0.6862745098039216, ...
# 3        [0.0, 0.17254901960784313, 0.3568627450980392,...
# 4        [0.0, 0.1568627450980392, 0.6862745098039216, ...
# ...                                                    ...
# 1265652  [0.0, 0.20392156862745098, 0.24705882352941178...
# 1265653  [0.0, 0.20392156862745098, 0.0, 0.0, 0.2509803...
# 1265654  [0.0, 0.20392156862745098, 0.24705882352941178...
# 1265655  [0.0, 0.20392156862745098, 0.24705882352941178...
# 1265656  [0.0, 0.20392156862745098, 0.0, 0.0, 0.2509803...
#
# [1265657 rows x 9 columns]

# %%
streams_lst = list(df['Stream Index'].unique())

# %%
len(streams_lst)
# Out:
# 167232

# %%
# 70% of benign data for train, 30% for test benign

# %%
#random.seed(0)
#mlist = random.sample(streams_lst, 61492)

# %%
#len(imlist)

# %%
#df_train = df.loc[df['Stream Index'].isin(imlist)]
#df_train = df_train.reset_index(inplace = False)

# %%
#df_test = df.loc[~df['Stream Index'].isin(imlist)]
#df_test = df_test.reset_index(inplace = False)

# %%
#streams_lst1 = list(df_test['Stream Index'].unique())

# %%
#len(streams_lst1)

# %%
streams_lst = list(df['Stream Index'].unique())
print('Total number of flows in class:', len(streams_lst))    
random.shuffle(streams_lst)

# Directory path where to save the CSV files
directory_path = 'Friday_ddos_all/'

for PKT in range(3, 16):
    
    file_name = f'friday_ddos_{PKT}pkt.csv'
    file_path = directory_path + file_name
    

    data = []
    num_pkt = PKT
    pkt_val_pad = [0] * 25


    for j in range(len(streams_lst)):

        df_stream = df[df['Stream Index'] == streams_lst[j]]


        df_stream = df_stream.sort_values(by = 'Epoch Time')
        df_stream = df_stream.reset_index(drop=True)


        if len(df_stream) >= num_pkt:

            src_node = (int(netaddr.IPAddress(df_stream['Source IP'][0])), int(df_stream['Source Port'][0]))
            dst_node = (int(netaddr.IPAddress(df_stream['Dst IP'][0])), int(df_stream['Dst Port'][0]))
            stream_no = df_stream['Stream Index'][0]

            pkt_val_seq = []

            for k in range(0, num_pkt):

                pkt_val = []
                if df_stream['Direction'][k] == 'fwd':
                    pkt_val = [*df_stream['pkt_header_values'][k], *pkt_val_pad]
                else:
                    pkt_val = [*pkt_val_pad, *df_stream['pkt_header_values'][k]]

                pkt_val_seq.extend(pkt_val)

            data.append([src_node, dst_node, stream_no, pkt_val_seq])

    df2 = pd.DataFrame(data, columns= ['src_node', 'dst_node', 'stream_number', 'pkt_vals'])
    
    df2.to_csv(file_path, index=False)
# Out:
# Total number of flows in class: 167232
