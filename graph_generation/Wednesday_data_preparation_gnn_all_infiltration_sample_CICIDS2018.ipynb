# %%
import pickle 
import numpy as np
import pandas as pd
import statistics
from PIL import Image
import os 
import random
import time
import matplotlib.pyplot as plt
import netaddr

# %%
#pip install netaddr

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\Jalal\\Box\\GNN Project\\Code files'

# %%
#directory should change based on the device, for laptop it should be users//jalal for office desktop it is users//jghadermazi

# %%
wed_data = pd.read_pickle(r'C:\\Users\\Jalal\\Box\\GNN Project\\CICIDS2018\\Infiltration-11\\Wednesday-28-02-2018_Packet_Level_Data_Infiltration.pkl')

# %%
df1 = wed_data1.copy()

# %%
df1[['Payload']] = df1[['Payload']].replace('', '00')

# %%
df1
# Out:
#                   Epoch Time        Source IP           Dst IP  Source Port  \
# 0       1519829100.295341000     172.31.69.24  131.202.242.193         3389
# 1       1519829101.129340000  131.202.242.193     172.31.69.24        15654
# 2       1519829101.310064000     172.31.69.24  131.202.242.193         3389
# 3       1519829102.145328000      87.230.72.8     172.31.69.24        51266
# 4       1519829102.146883000     172.31.69.24      87.230.72.8         3389
# ...                      ...              ...              ...          ...
# 324136  1519843258.956574000  131.202.242.193     172.31.69.24        15654
# 324137  1519843258.956594000     172.31.69.24  131.202.242.193         3389
# 324138  1519843258.979329000  131.202.242.193     172.31.69.24        15654
# 324139  1519843258.988411000  131.202.242.193     172.31.69.24        15654
# 324140  1519843258.988453000     172.31.69.24  131.202.242.193         3389
#
#         Dst Port Stream Index Sequence Number                    Eth Header  \
# 0          15654         1908          101110  02ca69c46d0602c680d4fa3a0800
# 1           3389         1908          517577  02c680d4fa3a02ca69c46d060800
# 2          15654         1908          101161  02ca69c46d0602c680d4fa3a0800
# 3           3389         2140             253  02c680d4fa3a02ca69c46d060800
# 4          51266         2140            1193  02ca69c46d0602c680d4fa3a0800
# ...          ...          ...             ...                           ...
# 324136      3389         1908         1197629  02c680d4fa3a02ca69c46d060800
# 324137     15654         1908          809758  02ca69c46d0602c680d4fa3a0800
# 324138      3389         1908         1197672  02c680d4fa3a02ca69c46d060800
# 324139      3389         1908         1197729  02c680d4fa3a02ca69c46d060800
# 324140     15654         1908          809758  02ca69c46d0602c680d4fa3a0800
#
#                                        IP Header  \
# 0       4500005b793e40008006199bac1f451883caf2c1
# 1       4500002832c740006d06734583caf2c1ac1f4518
# 2       4500005b7942400080061997ac1f451883caf2c1
# 3       450200ae50ef40006506333357e64808ac1f4518
# 4       45020063456e4000800623ffac1f451857e64808
# ...                                          ...
# 324136  450000532d6140006d06788083caf2c1ac1f4518
# 324137  450000285c9b400080063671ac1f451883caf2c1
# 324138  450000612d6240006d06787183caf2c1ac1f4518
# 324139  450000532d6340006d06787e83caf2c1ac1f4518
# 324140  450000285c9c400080063670ac1f451883caf2c1
#
#                                       TCP Header TCP Option  \
# 0       0d3d3d261e4b814e28877d485018f84ca5920000
# 1       3d260d3d28877d481e4b8181501000feb7130000
# 2       0d3d3d261e4b818128877d485018f84c02640000
# 3       c8420d3d241957d7041274ad501800fbe1a70000
# 4       0d3dc842041274ad2419585d5018f87ee7e90000
# ...                                          ...        ...
# 324136  3d260d3d2891ddbc1e565176501800ff7a410000
# 324137  0d3d3d261e5651762891dde75010f75290150000
# 324138  3d260d3d2891dde71e565176501800ffb0d70000
# 324139  3d260d3d2891de201e565176501800ffc7c20000
# 324140  0d3d3d261e5651762891de4b5010f6ee90150000
#
#                                                   Payload Direction  \
# 0       170303002e000000000000070e84491f4cb00578bc75c3...       bwd
# 1                                                      00       fwd
# 2       170303002e000000000000070ff406ecc38edb404ab024...       bwd
# 3       16030100461000004241044ebf809d25329a1da4fe749a...       fwd
# 4       1403010001011603010030ef49c2fe6cd178b7c458855e...       bwd
# ...                                                   ...       ...
# 324136  1703030026000000000000616f471cc6b1c82937d1ff1f...       fwd
# 324137                                                 00       bwd
# 324138  170303003400000000000061704d1fecc9da9cefefa250...       fwd
# 324139  170303002600000000000061711a4b1c855c8ed5606fcb...       fwd
# 324140                                                 00       bwd
#
#         Binary Label  Class Label
# 0                  1           11
# 1                  1           11
# 2                  1           11
# 3                  1           11
# 4                  1           11
# ...              ...          ...
# 324136             1           11
# 324137             1           11
# 324138             1           11
# 324139             1           11
# 324140             1           11
#
# [324141 rows x 15 columns]

# %%
#Web attack-Brute Force 1
# Web attack-XSS 2
# Web attack-Sql injection 3
# FTP patator 4
# SSH Patator 5
# DoS GoldenEye 6
# DoS Slowloris 7
# DoS Hulk 8
# DoS Slowhttptest 9
# DDoS 10
# Infiltration 11

# %%
df1['Class Label'].value_counts()
# Out:
# 11    324141
# Name: Class Label, dtype: int64

# %%
df = df1[df1['Class Label']== 11]

# %%
df = df.reset_index(inplace = False)

# %%
df
# Out:
#          index            Epoch Time        Source IP           Dst IP  \
# 0            0  1519829100.295341000     172.31.69.24  131.202.242.193
# 1            1  1519829101.129340000  131.202.242.193     172.31.69.24
# 2            2  1519829101.310064000     172.31.69.24  131.202.242.193
# 3            3  1519829102.145328000      87.230.72.8     172.31.69.24
# 4            4  1519829102.146883000     172.31.69.24      87.230.72.8
# ...        ...                   ...              ...              ...
# 324136  324136  1519843258.956574000  131.202.242.193     172.31.69.24
# 324137  324137  1519843258.956594000     172.31.69.24  131.202.242.193
# 324138  324138  1519843258.979329000  131.202.242.193     172.31.69.24
# 324139  324139  1519843258.988411000  131.202.242.193     172.31.69.24
# 324140  324140  1519843258.988453000     172.31.69.24  131.202.242.193
#
#         Source Port  Dst Port Stream Index Sequence Number  \
# 0              3389     15654         1908          101110
# 1             15654      3389         1908          517577
# 2              3389     15654         1908          101161
# 3             51266      3389         2140             253
# 4              3389     51266         2140            1193
# ...             ...       ...          ...             ...
# 324136        15654      3389         1908         1197629
# 324137         3389     15654         1908          809758
# 324138        15654      3389         1908         1197672
# 324139        15654      3389         1908         1197729
# 324140         3389     15654         1908          809758
#
#                           Eth Header  \
# 0       02ca69c46d0602c680d4fa3a0800
# 1       02c680d4fa3a02ca69c46d060800
# 2       02ca69c46d0602c680d4fa3a0800
# 3       02c680d4fa3a02ca69c46d060800
# 4       02ca69c46d0602c680d4fa3a0800
# ...                              ...
# 324136  02c680d4fa3a02ca69c46d060800
# 324137  02ca69c46d0602c680d4fa3a0800
# 324138  02c680d4fa3a02ca69c46d060800
# 324139  02c680d4fa3a02ca69c46d060800
# 324140  02ca69c46d0602c680d4fa3a0800
#
#                                        IP Header  \
# 0       4500005b793e40008006199bac1f451883caf2c1
# 1       4500002832c740006d06734583caf2c1ac1f4518
# 2       4500005b7942400080061997ac1f451883caf2c1
# 3       450200ae50ef40006506333357e64808ac1f4518
# 4       45020063456e4000800623ffac1f451857e64808
# ...                                          ...
# 324136  450000532d6140006d06788083caf2c1ac1f4518
# 324137  450000285c9b400080063671ac1f451883caf2c1
# 324138  450000612d6240006d06787183caf2c1ac1f4518
# 324139  450000532d6340006d06787e83caf2c1ac1f4518
# 324140  450000285c9c400080063670ac1f451883caf2c1
#
#                                       TCP Header TCP Option  \
# 0       0d3d3d261e4b814e28877d485018f84ca5920000
# 1       3d260d3d28877d481e4b8181501000feb7130000
# 2       0d3d3d261e4b818128877d485018f84c02640000
# 3       c8420d3d241957d7041274ad501800fbe1a70000
# 4       0d3dc842041274ad2419585d5018f87ee7e90000
# ...                                          ...        ...
# 324136  3d260d3d2891ddbc1e565176501800ff7a410000
# 324137  0d3d3d261e5651762891dde75010f75290150000
# 324138  3d260d3d2891dde71e565176501800ffb0d70000
# 324139  3d260d3d2891de201e565176501800ffc7c20000
# 324140  0d3d3d261e5651762891de4b5010f6ee90150000
#
#                                                   Payload Direction  \
# 0       170303002e000000000000070e84491f4cb00578bc75c3...       bwd
# 1                                                      00       fwd
# 2       170303002e000000000000070ff406ecc38edb404ab024...       bwd
# 3       16030100461000004241044ebf809d25329a1da4fe749a...       fwd
# 4       1403010001011603010030ef49c2fe6cd178b7c458855e...       bwd
# ...                                                   ...       ...
# 324136  1703030026000000000000616f471cc6b1c82937d1ff1f...       fwd
# 324137                                                 00       bwd
# 324138  170303003400000000000061704d1fecc9da9cefefa250...       fwd
# 324139  170303002600000000000061711a4b1c855c8ed5606fcb...       fwd
# 324140                                                 00       bwd
#
#         Binary Label  Class Label
# 0                  1           11
# 1                  1           11
# 2                  1           11
# 3                  1           11
# 4                  1           11
# ...              ...          ...
# 324136             1           11
# 324137             1           11
# 324138             1           11
# 324139             1           11
# 324140             1           11
#
# [324141 rows x 16 columns]

# %%
ip_header_lst = []

for i in range(len(df)):
    x = df['IP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 9, 12, 13, 14, 15, 16, 17, 18, 19])
    
    output = np.abs(output.astype(float))/255
    ip_header_lst.append(output)
    
df['IP Header Array'] = ip_header_lst

# %%
tcp_header_lst = []

for i in range(len(df)):
    x = df['TCP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 2, 3])
    output = np.abs(output.astype(float))/255
    
    tcp_header_lst.append(output)
    
df['TCP Header Array'] = tcp_header_lst

# %%
df['pkt_header_values'] = df.apply(lambda x : (np.append(x['IP Header Array'], x['TCP Header Array'])), axis=1)

# %%
new_cols = ['Source IP', 'Dst IP', 'Source Port', 'Dst Port','Epoch Time','Stream Index', 'Sequence Number', 'Direction', 'pkt_header_values']
df = df[new_cols]

# %%
df
# Out:
#               Source IP           Dst IP  Source Port  Dst Port  \
# 0          172.31.69.24  131.202.242.193         3389     15654
# 1       131.202.242.193     172.31.69.24        15654      3389
# 2          172.31.69.24  131.202.242.193         3389     15654
# 3           87.230.72.8     172.31.69.24        51266      3389
# 4          172.31.69.24      87.230.72.8         3389     51266
# ...                 ...              ...          ...       ...
# 324136  131.202.242.193     172.31.69.24        15654      3389
# 324137     172.31.69.24  131.202.242.193         3389     15654
# 324138  131.202.242.193     172.31.69.24        15654      3389
# 324139  131.202.242.193     172.31.69.24        15654      3389
# 324140     172.31.69.24  131.202.242.193         3389     15654
#
#                   Epoch Time Stream Index Sequence Number Direction  \
# 0       1519829100.295341000         1908          101110       bwd
# 1       1519829101.129340000         1908          517577       fwd
# 2       1519829101.310064000         1908          101161       bwd
# 3       1519829102.145328000         2140             253       fwd
# 4       1519829102.146883000         2140            1193       bwd
# ...                      ...          ...             ...       ...
# 324136  1519843258.956574000         1908         1197629       fwd
# 324137  1519843258.956594000         1908          809758       bwd
# 324138  1519843258.979329000         1908         1197672       fwd
# 324139  1519843258.988411000         1908         1197729       fwd
# 324140  1519843258.988453000         1908          809758       bwd
#
#                                         pkt_header_values
# 0       [0.0, 0.3568627450980392, 0.4745098039215686, ...
# 1       [0.0, 0.1568627450980392, 0.19607843137254902,...
# 2       [0.0, 0.3568627450980392, 0.4745098039215686, ...
# 3       [0.0, 0.6823529411764706, 0.3137254901960784, ...
# 4       [0.0, 0.38823529411764707, 0.27058823529411763...
# ...                                                   ...
# 324136  [0.0, 0.3254901960784314, 0.17647058823529413,...
# 324137  [0.0, 0.1568627450980392, 0.3607843137254902, ...
# 324138  [0.0, 0.3803921568627451, 0.17647058823529413,...
# 324139  [0.0, 0.3254901960784314, 0.17647058823529413,...
# 324140  [0.0, 0.1568627450980392, 0.3607843137254902, ...
#
# [324141 rows x 9 columns]

# %%
# 70% of benign data for train, 30% for test benign

# %%
streams_lst = list(df['Stream Index'].unique())
streams_lst = streams_lst[0:2000]
print('Total number of flows in class:', len(streams_lst))    
random.shuffle(streams_lst)

# Directory path where to save the CSV files
directory_path = '2018_infiltration/'

for PKT in range(2, 16):
    
    file_name = f'2018_infiltration_{PKT}pkt.csv'
    file_path = directory_path + file_name
    

    data = []
    num_pkt = PKT
    pkt_val_pad = [0] * 25


    for j in range(len(streams_lst)):

        df_stream = df[df['Stream Index'] == streams_lst[j]]


        df_stream = df_stream.sort_values(by = 'Epoch Time')
        df_stream = df_stream.reset_index(drop=True)


        if len(df_stream) >= num_pkt:

            src_node = (int(netaddr.IPAddress(df_stream['Source IP'][0])), int(df_stream['Source Port'][0]))
            dst_node = (int(netaddr.IPAddress(df_stream['Dst IP'][0])), int(df_stream['Dst Port'][0]))
            stream_no = df_stream['Stream Index'][0]

            pkt_val_seq = []

            for k in range(0, num_pkt):

                pkt_val = []
                if df_stream['Direction'][k] == 'fwd':
                    pkt_val = [*df_stream['pkt_header_values'][k], *pkt_val_pad]
                else:
                    pkt_val = [*pkt_val_pad, *df_stream['pkt_header_values'][k]]

                pkt_val_seq.extend(pkt_val)

            data.append([src_node, dst_node, stream_no, pkt_val_seq])

    df1 = pd.DataFrame(data, columns= ['src_node', 'dst_node', 'stream_number', 'pkt_vals'])
    
    df1.to_csv(file_path, index=False)
# Out:
# Total number of flows in class: 2000
