# %%
import pickle 
import numpy as np
import pandas as pd
import statistics
from PIL import Image
import os 
import random
import time
import matplotlib.pyplot as plt
import netaddr

# %%
#pip install netaddr

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\Jalal\\Box\\GNN Project\\Code files'

# %%
#directory should change based on the device, for laptop it should be users//jalal for office desktop it is users//jghadermazi

# %%
wed_data1 = pd.read_pickle(r'C:\\Users\\Jalal\\Box\\GNN Project\\CICIDS2018\\Webattack-1,2,3\\Friday-23-02-2018_Packet_Level_Data_Attack.pkl')

# %%
wed_data2 = pd.read_pickle(r'C:\\Users\\Jalal\\Box\\GNN Project\\CICIDS2018\\Webattack-1,2,3\\Thursday-22-02-2018_Packet_Level_Data_Attack.pkl')

# %%
wed_data = pd.concat([wed_data1 , wed_data2 ], axis =0)

# %%
df1 = wed_data.copy()

# %%
df1[['Payload']] = df1[['Payload']].replace('', '00')

# %%
df1
# Out:
#                  Epoch Time        Source IP           Dst IP  Source Port  \
# 0      1519388260.146291000     172.31.69.28  131.202.242.193           22
# 1      1519388260.146339000     172.31.69.28  131.202.242.193           22
# 2      1519388260.146370000     172.31.69.28  131.202.242.193           22
# 3      1519388260.183812000  131.202.242.193     172.31.69.28        31808
# 4      1519388260.184073000  131.202.242.193     172.31.69.28        31808
# ...                     ...              ...              ...          ...
# 30316  1519323660.985693000    18.218.115.60     172.31.69.28        56463
# 30317  1519323660.987861000     172.31.69.28    18.218.115.60           80
# 30318  1519323660.988274000    18.218.115.60     172.31.69.28        56463
# 30319  1519323661.991359000    18.218.115.60     172.31.69.28        56463
# 30320  1519323661.993494000     172.31.69.28    18.218.115.60           80
#
#        Dst Port Stream Index Sequence Number                    Eth Header  \
# 0         31808            0               1  02ca69c46d06029e424890aa0800
# 1         31808            0              65  02ca69c46d06029e424890aa0800
# 2         31808            0             193  02ca69c46d06029e424890aa0800
# 3            22            0               1  029e424890aa02ca69c46d060800
# 4            22            0               1  029e424890aa02ca69c46d060800
# ...         ...          ...             ...                           ...
# 30316        80          855           24920  029e424890aa02ca69c46d060800
# 30317     56463          855           84597  02ca69c46d06029e424890aa0800
# 30318        80          855           25600  029e424890aa02ca69c46d060800
# 30319        80          855           25600  029e424890aa02ca69c46d060800
# 30320     56463          855           86528  02ca69c46d06029e424890aa0800
#
#                                       IP Header  \
# 0      4510006893aa400040063f0eac1f451c83caf2c1
# 1      451000a893ab400040063ecdac1f451c83caf2c1
# 2      4510006893ac400040063f0cac1f451c83caf2c1
# 3      450000285a8040006d064b8883caf2c1ac1f451c
# 4      450000285a8140006d064b8783caf2c1ac1f451c
# ...                                         ...
# 30316  450002d03d6240007f06447412da733cac1f451c
# 30317  450007b3d2c940004006e929ac1f451c12da733c
# 30318  450000283d6340007f06471b12da733cac1f451c
# 30319  450001d93d6440007f06456912da733cac1f451c
# 30320  4500074dd2cb40004006e98dac1f451c12da733c
#
#                                      TCP Header TCP Option  \
# 0      00167c407d80ca0fe4d04518501800fd68220000
# 1      00167c407d80ca4fe4d04518501800fd68620000
# 2      00167c407d80cacfe4d04518501800fd68220000
# 3      7c400016e4d045187d80c94f5010010059fd0000
# 4      7c400016e4d045187d80ca0f501000ff593e0000
# ...                                         ...        ...
# 30316  dc8f00500d4596106ae05e2c5018080510550000
# 30317  0050dc8f6ae05e2c0d4598b8501802b97ef70000
# 30318  dc8f00500d4598b86ae065b750100805dd080000
# 30319  dc8f00500d4598b86ae065b7501808052ce90000
# 30320  0050dc8f6ae065b70d459a69501802c47e910000
#
#                                                  Payload Direction  \
# 0      e0f38546b3f48ad96aa348f1bd179c3b616600a1ac54d8...       fwd
# 1      a7dfe0e00e28b51cfbae92ddad436bec3099b45e3f672a...       bwd
# 2      56596fcdbe3cc10b870591b162f43c89d517597e6ea152...       fwd
# 3                                                     00       fwd
# 4                                                     00       bwd
# ...                                                  ...       ...
# 30316  474554202f445657412f76756c6e65726162696c697469...       bwd
# 30317  485454502f312e3120323030204f4b0d0a446174653a20...       fwd
# 30318                                                 00       fwd
# 30319  474554202f445657412f76756c6e65726162696c697469...       bwd
# 30320  485454502f312e3120323030204f4b0d0a446174653a20...       fwd
#
#        Binary Label  Class Label
# 0               1.0          1.0
# 1               1.0          1.0
# 2               1.0          1.0
# 3               1.0          1.0
# 4               1.0          1.0
# ...             ...          ...
# 30316           1.0          3.0
# 30317           1.0          3.0
# 30318           1.0          3.0
# 30319           1.0          3.0
# 30320           1.0          3.0
#
# [69731 rows x 15 columns]

# %%
#Web attack-Brute Force 1
# Web attack-XSS 2
# Web attack-Sql injection 3
# FTP patator 4
# SSH Patator 5
# DoS GoldenEye 6
# DoS Slowloris 7
# DoS Hulk 8
# DoS Slowhttptest 9
# DDoS 10
# Infiltration 11

# %%
df1['Class Label'].value_counts()
# Out:
# 1.0    34955
# 2.0    34195
# 3.0      581
# Name: Class Label, dtype: int64

# %%
df = df1[df1['Class Label']== 3]

# %%
df = df.reset_index(inplace = False)

# %%
df
# Out:
#      index            Epoch Time      Source IP         Dst IP  Source Port  \
# 0    39061  1519408795.709644000  18.218.115.60   172.31.69.28        61677
# 1    39062  1519408795.711801000   172.31.69.28  18.218.115.60           80
# 2    39063  1519408795.712197000  18.218.115.60   172.31.69.28        61677
# 3    39064  1519408795.832748000  18.218.115.60   172.31.69.28        61677
# 4    39065  1519408795.834929000   172.31.69.28  18.218.115.60           80
# ..     ...                   ...            ...            ...          ...
# 576  30316  1519323660.985693000  18.218.115.60   172.31.69.28        56463
# 577  30317  1519323660.987861000   172.31.69.28  18.218.115.60           80
# 578  30318  1519323660.988274000  18.218.115.60   172.31.69.28        56463
# 579  30319  1519323661.991359000  18.218.115.60   172.31.69.28        56463
# 580  30320  1519323661.993494000   172.31.69.28  18.218.115.60           80
#
#      Dst Port Stream Index Sequence Number                    Eth Header  \
# 0          80          785           25167  029e424890aa02ca69c46d060800
# 1       61677          785           84706  02ca69c46d06029e424890aa0800
# 2          80          785           25600  029e424890aa02ca69c46d060800
# 3          80          785           25600  029e424890aa02ca69c46d060800
# 4       61677          785           86533  02ca69c46d06029e424890aa0800
# ..        ...          ...             ...                           ...
# 576        80          855           24920  029e424890aa02ca69c46d060800
# 577     56463          855           84597  02ca69c46d06029e424890aa0800
# 578        80          855           25600  029e424890aa02ca69c46d060800
# 579        80          855           25600  029e424890aa02ca69c46d060800
# 580     56463          855           86528  02ca69c46d06029e424890aa0800
#
#                                     IP Header  \
# 0    450001d91ca040007f06662d12da733cac1f451c
# 1    4500074bc56740004006f6f3ac1f451c12da733c
# 2    450000281ca140007f0667dd12da733cac1f451c
# 3    450002d01ca240007f06653412da733cac1f451c
# 4    450007b5c56940004006f687ac1f451c12da733c
# ..                                        ...
# 576  450002d03d6240007f06447412da733cac1f451c
# 577  450007b3d2c940004006e929ac1f451c12da733c
# 578  450000283d6340007f06471b12da733cac1f451c
# 579  450001d93d6440007f06456912da733cac1f451c
# 580  4500074dd2cb40004006e98dac1f451c12da733c
#
#                                    TCP Header TCP Option  \
# 0    f0ed005020040bd4139feba35018080593970000
# 1    0050f0ed139feba320040d85501802bb7e8f0000
# 2    f0ed005020040d85139ff2c6501008050b510000
# 3    f0ed005020040d85139ff2c6501808059d010000
# 4    0050f0ed139ff2c62004102d501802c67ef90000
# ..                                        ...        ...
# 576  dc8f00500d4596106ae05e2c5018080510550000
# 577  0050dc8f6ae05e2c0d4598b8501802b97ef70000
# 578  dc8f00500d4598b86ae065b750100805dd080000
# 579  dc8f00500d4598b86ae065b7501808052ce90000
# 580  0050dc8f6ae065b70d459a69501802c47e910000
#
#                                                Payload Direction  \
# 0    474554202f445657412f76756c6e65726162696c697469...       fwd
# 1    485454502f312e3120323030204f4b0d0a446174653a20...       bwd
# 2                                                   00       fwd
# 3    474554202f445657412f76756c6e65726162696c697469...       fwd
# 4    485454502f312e3120323030204f4b0d0a446174653a20...       bwd
# ..                                                 ...       ...
# 576  474554202f445657412f76756c6e65726162696c697469...       bwd
# 577  485454502f312e3120323030204f4b0d0a446174653a20...       fwd
# 578                                                 00       fwd
# 579  474554202f445657412f76756c6e65726162696c697469...       bwd
# 580  485454502f312e3120323030204f4b0d0a446174653a20...       fwd
#
#      Binary Label  Class Label
# 0             1.0          3.0
# 1             1.0          3.0
# 2             1.0          3.0
# 3             1.0          3.0
# 4             1.0          3.0
# ..            ...          ...
# 576           1.0          3.0
# 577           1.0          3.0
# 578           1.0          3.0
# 579           1.0          3.0
# 580           1.0          3.0
#
# [581 rows x 16 columns]

# %%
ip_header_lst = []

for i in range(len(df)):
    x = df['IP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 9, 12, 13, 14, 15, 16, 17, 18, 19])
    
    output = np.abs(output.astype(float))/255
    ip_header_lst.append(output)
    
df['IP Header Array'] = ip_header_lst

# %%
tcp_header_lst = []

for i in range(len(df)):
    x = df['TCP Header'][i]
    byte_array = bytes.fromhex(x)
    byte_lst = list(byte_array)
    if (len(byte_lst) < 20):
            output = np.pad(byte_lst, (0, 20-len(byte_lst)), 'constant')
    else:
            output = np.array(byte_lst[0:20].copy())
            
    output = np.delete(output, [0, 1, 2, 3])
    output = np.abs(output.astype(float))/255
    
    tcp_header_lst.append(output)
    
df['TCP Header Array'] = tcp_header_lst

# %%
df['pkt_header_values'] = df.apply(lambda x : (np.append(x['IP Header Array'], x['TCP Header Array'])), axis=1)

# %%
new_cols = ['Source IP', 'Dst IP', 'Source Port', 'Dst Port','Epoch Time','Stream Index', 'Sequence Number', 'Direction', 'pkt_header_values']
df = df[new_cols]

# %%
df
# Out:
#          Source IP         Dst IP  Source Port  Dst Port  \
# 0    18.218.115.60   172.31.69.28        61677        80
# 1     172.31.69.28  18.218.115.60           80     61677
# 2    18.218.115.60   172.31.69.28        61677        80
# 3    18.218.115.60   172.31.69.28        61677        80
# 4     172.31.69.28  18.218.115.60           80     61677
# ..             ...            ...          ...       ...
# 576  18.218.115.60   172.31.69.28        56463        80
# 577   172.31.69.28  18.218.115.60           80     56463
# 578  18.218.115.60   172.31.69.28        56463        80
# 579  18.218.115.60   172.31.69.28        56463        80
# 580   172.31.69.28  18.218.115.60           80     56463
#
#                Epoch Time Stream Index Sequence Number Direction  \
# 0    1519408795.709644000          785           25167       fwd
# 1    1519408795.711801000          785           84706       bwd
# 2    1519408795.712197000          785           25600       fwd
# 3    1519408795.832748000          785           25600       fwd
# 4    1519408795.834929000          785           86533       bwd
# ..                    ...          ...             ...       ...
# 576  1519323660.985693000          855           24920       bwd
# 577  1519323660.987861000          855           84597       fwd
# 578  1519323660.988274000          855           25600       fwd
# 579  1519323661.991359000          855           25600       bwd
# 580  1519323661.993494000          855           86528       fwd
#
#                                      pkt_header_values
# 0    [0.00392156862745098, 0.8509803921568627, 0.10...
# 1    [0.027450980392156862, 0.29411764705882354, 0....
# 2    [0.0, 0.1568627450980392, 0.10980392156862745,...
# 3    [0.00784313725490196, 0.8156862745098039, 0.10...
# 4    [0.027450980392156862, 0.7098039215686275, 0.7...
# ..                                                 ...
# 576  [0.00784313725490196, 0.8156862745098039, 0.23...
# 577  [0.027450980392156862, 0.7019607843137254, 0.8...
# 578  [0.0, 0.1568627450980392, 0.23921568627450981,...
# 579  [0.00392156862745098, 0.8509803921568627, 0.23...
# 580  [0.027450980392156862, 0.30196078431372547, 0....
#
# [581 rows x 9 columns]

# %%
# 70% of benign data for train, 30% for test benign

# %%
streams_lst = list(df['Stream Index'].unique())
streams_lst = streams_lst[0:2000]
print('Total number of flows in class:', len(streams_lst))    
random.shuffle(streams_lst)

# Directory path where to save the CSV files
directory_path = '2018_wa_sql/'

for PKT in range(2, 16):
    
    file_name = f'2018_wa_sql_{PKT}pkt.csv'
    file_path = directory_path + file_name
    

    data = []
    num_pkt = PKT
    pkt_val_pad = [0] * 25


    for j in range(len(streams_lst)):

        df_stream = df[df['Stream Index'] == streams_lst[j]]


        df_stream = df_stream.sort_values(by = 'Epoch Time')
        df_stream = df_stream.reset_index(drop=True)


        if len(df_stream) >= num_pkt:

            src_node = (int(netaddr.IPAddress(df_stream['Source IP'][0])), int(df_stream['Source Port'][0]))
            dst_node = (int(netaddr.IPAddress(df_stream['Dst IP'][0])), int(df_stream['Dst Port'][0]))
            stream_no = df_stream['Stream Index'][0]

            pkt_val_seq = []

            for k in range(0, num_pkt):

                pkt_val = []
                if df_stream['Direction'][k] == 'fwd':
                    pkt_val = [*df_stream['pkt_header_values'][k], *pkt_val_pad]
                else:
                    pkt_val = [*pkt_val_pad, *df_stream['pkt_header_values'][k]]

                pkt_val_seq.extend(pkt_val)

            data.append([src_node, dst_node, stream_no, pkt_val_seq])

    df1 = pd.DataFrame(data, columns= ['src_node', 'dst_node', 'stream_number', 'pkt_vals'])
    
    df1.to_csv(file_path, index=False)
# Out:
# Total number of flows in class: 5
